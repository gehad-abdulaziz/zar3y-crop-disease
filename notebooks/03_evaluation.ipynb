# %% [markdown]
# # 03. Evaluation & Quantization
# Measuring performance and optimizing for mobile.

# %%
from src.evaluate import evaluate_model
from src.quantize_tflite import quantize_and_benchmark

evaluate_model()
quantize_and_benchmark()
