# %% [markdown]
# # 02. Training Pipeline
# Training the MobileNetV2 model using Transfer Learning.

# %%
from src.train import build_model, train_model
from src.data_prep import prepare_data

# Step 1: Prep
counts, classes = prepare_data()

# Step 2: Training
history = train_model() # This would run the full pipeline
print('Training complete!')
